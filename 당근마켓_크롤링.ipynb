# %%
pip install beautifulsoup4

# %%
import requests

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
#홈페이지
html = urlopen("https://www.daangn.com/")

bsObject = BeautifulSoup(html, "html.parser")

for link in bsObject.find_all('img'):
  print(link.text.strip(), link.get('src'))

for link in bsObject.find_all('a'):
  print(link.text.strip(), link.get('href'))
# Out:
#  https://www.facebook.com/tr?id=992961397411651&ev=PageView&noscript=1
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/logo-basic-24b18257ac4ef693c02233bf21e9cb7ecbf43ebd8d5b40c24d99e14094a44c81.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/search-icon-7008edd4f9aaa32188f55e65258f1c1905d7a9d1a3ca2a07ae809b5535380f14.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/apple-store-3a664174124650d63cae365bc55586fc5ff27b822b1b97788fc4af77d73d00c8.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/google-play-c9ad0fc573cd01e2b982df5de6709a3d8d7cec8d9b58a5c08db7da0b92a32a75.svg
#  https://dnvefa72aowie.cloudfront.net/origin/article/202108/a70f23a62cdec5ece65516ec68f0b62466798386e6ff494339226027badc8509.webp?q=82&s=300x300&t=crop
#  https://dnvefa72aowie.cloudfront.net/origin/article/202108/B91444B250AE3F708A85C6918B3342BCCDCAEB0208AAC9F238995BCD5FEE7B73.jpg?q=82&s=300x300&t=crop
# ...

# %%
#인기매물
webpage = requests.get("https://www.daangn.com/hot_articles")
soup = BeautifulSoup(webpage.content, "html.parser")

getItem = soup.select("#content > section.cards-wrap > article")
print(getItem[0])

for item in getItem:
 print( item.select('a > div.card-desc > h2 ')[0].text.strip(), end=",")

 print( item.select('a > div.card-desc > div.card-price')[0].text.strip(),end=",")

 print( item.select('a > div.card-desc > div.card-region-name')[0].text.strip(),end=",")

 print( item.select('a > div.card-desc > div.card-counts')[0].text.strip().replace(' ', '').replace('\n', '').replace('∙', ','))

 print( item.select('a > div.card-photo > img ')[0])
# Out:
# <article class="card-top ">
# <a class="card-link " data-event-label="274936911" href="/articles/274936911">
# <div class="card-photo ">
# <img alt="타이틀리스트 골프백 정품" src="https://dnvefa72aowie.cloudfront.net/origin/article/202108/a70f23a62cdec5ece65516ec68f0b62466798386e6ff494339226027badc8509.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">타이틀리스트 골프백 정품</h2>
# <div class="card-price ">
#         30,000원
#       </div>
# <div class="card-region-name">
#         경기도 안양시 동안구 범계동
#       </div>
# <div class="card-counts">
# <span>
#             관심 10
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article>
# 타이틀리스트 골프백 정품,30,000원,경기도 안양시 동안구 범계동,관심10,채팅13
# <img alt="타이틀리스트 골프백 정품" src="https://dnvefa72aowie.cloudfront.net/origin/article/202108/a70f23a62cdec5ece65516ec68f0b62466798386e6ff494339226027badc8509.webp?q=82&amp;s=300x300&amp;t=crop"/>
# ...

# %%
#자전거
html = urlopen("https://www.daangn.com/search/%EC%9E%90%EC%A0%84%EA%B1%B0")

bsObject = BeautifulSoup(html, "html.parser")

for link in bsObject.find_all('img'):
  print(link.text.strip(), link.get('src'))

for link in bsObject.find_all('a'):
  print(link.text.strip(),link.get('img-alt'), link.get('article-title'),link.get('article-content'), link.get('article-region-name'),link.get('article-price'))
# Out:
#  https://www.facebook.com/tr?id=992961397411651&ev=PageView&noscript=1
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/logo-basic-24b18257ac4ef693c02233bf21e9cb7ecbf43ebd8d5b40c24d99e14094a44c81.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/search-icon-7008edd4f9aaa32188f55e65258f1c1905d7a9d1a3ca2a07ae809b5535380f14.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/apple-store-3a664174124650d63cae365bc55586fc5ff27b822b1b97788fc4af77d73d00c8.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/google-play-c9ad0fc573cd01e2b982df5de6709a3d8d7cec8d9b58a5c08db7da0b92a32a75.svg
#  https://dnvefa72aowie.cloudfront.net/origin/article/202108/b4ed25773a59dd71028ee3947e8e23699e0b0f97086e7ddb5d286d48f3852563.webp?q=82&s=300x300&t=crop
#  https://dnvefa72aowie.cloudfront.net/origin/article/202108/697e75b9d5a6c0c5503c5269458275f167fc9d8a81a4536f341865284f7fba85.webp?q=82&s=300x300&t=crop
# ...

# %%
#에어컨

html = urlopen("https://www.daangn.com/search/%EC%97%90%EC%96%B4%EC%BB%A8")

bsObject = BeautifulSoup(html, "html.parser")

for link in bsObject.find_all('img'):
  print(link.text.strip(), link.get('src'))

for link in bsObject.find_all('a'):
  print(link.text.strip(),link.get('img-alt'), link.get('article-title'),link.get('article-content'), link.get('article-region-name'),link.get('article-price'))
# Out:
#  https://www.facebook.com/tr?id=992961397411651&ev=PageView&noscript=1
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/logo-basic-24b18257ac4ef693c02233bf21e9cb7ecbf43ebd8d5b40c24d99e14094a44c81.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/search-icon-7008edd4f9aaa32188f55e65258f1c1905d7a9d1a3ca2a07ae809b5535380f14.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/apple-store-3a664174124650d63cae365bc55586fc5ff27b822b1b97788fc4af77d73d00c8.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/google-play-c9ad0fc573cd01e2b982df5de6709a3d8d7cec8d9b58a5c08db7da0b92a32a75.svg
#  https://dnvefa72aowie.cloudfront.net/origin/article/202108/1F53AFA279096BB2EA52451EDD98648B0A13E7198F6185C9E210E58DB370954F.jpg?q=82&s=300x300&t=crop
#  https://dnvefa72aowie.cloudfront.net/origin/article/202108/D780178F7FB2B1BC286472FD53AC317B38BFC063A92DA9C6D522F8237CA55B9D.jpg?q=82&s=300x300&t=crop
# ...

# %%
#냉장고

html = urlopen("https://www.daangn.com/search/%EB%83%89%EC%9E%A5%EA%B3%A0")

bsObject = BeautifulSoup(html, "html.parser")

for link in bsObject.find_all('img'):
  print(link.text.strip(), link.get('src'))

for link in bsObject.find_all('a'):
  print(link.text.strip(),link.get('img-alt'), link.get('article-title'),link.get('article-content'), link.get('article-region-name'),link.get('article-price'))
# Out:
#  https://www.facebook.com/tr?id=992961397411651&ev=PageView&noscript=1
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/logo-basic-24b18257ac4ef693c02233bf21e9cb7ecbf43ebd8d5b40c24d99e14094a44c81.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/search-icon-7008edd4f9aaa32188f55e65258f1c1905d7a9d1a3ca2a07ae809b5535380f14.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/apple-store-3a664174124650d63cae365bc55586fc5ff27b822b1b97788fc4af77d73d00c8.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/google-play-c9ad0fc573cd01e2b982df5de6709a3d8d7cec8d9b58a5c08db7da0b92a32a75.svg
#  https://dnvefa72aowie.cloudfront.net/origin/article/202108/216B813BDCA058309AA9E0AC08FE48F3194FB949649BC82F92459CFABE63267A.jpg?q=82&s=300x300&t=crop
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/like-8111aa74d4b1045d7d5943a901896992574dd94c090cef92c26ae53e8da58260.svg
# ...

# %%
#캠핑

html = urlopen("https://www.daangn.com/search/%EC%BA%A0%ED%95%91")

bsObject = BeautifulSoup(html, "html.parser")

for link in bsObject.find_all('img'):
  print(link.text.strip(), link.get('src'))

for link in bsObject.find_all('a'):
  print(link.text.strip(),link.get('img-alt'), link.get('article-title'),link.get('article-content'), link.get('article-region-name'),link.get('article-price'))
# Out:
#  https://www.facebook.com/tr?id=992961397411651&ev=PageView&noscript=1
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/logo-basic-24b18257ac4ef693c02233bf21e9cb7ecbf43ebd8d5b40c24d99e14094a44c81.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/search-icon-7008edd4f9aaa32188f55e65258f1c1905d7a9d1a3ca2a07ae809b5535380f14.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/apple-store-3a664174124650d63cae365bc55586fc5ff27b822b1b97788fc4af77d73d00c8.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/google-play-c9ad0fc573cd01e2b982df5de6709a3d8d7cec8d9b58a5c08db7da0b92a32a75.svg
#  https://dnvefa72aowie.cloudfront.net/origin/article/202108/696D3B16E8F2CEB3C3AF7553919037DD1EAB64CF74FAE769C5C32C74B49394BD.jpg?q=82&s=300x300&t=crop
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/like-8111aa74d4b1045d7d5943a901896992574dd94c090cef92c26ae53e8da58260.svg
# ...

# %%
#의자

html = urlopen("https://www.daangn.com/search/%EC%9D%98%EC%9E%90")

bsObject = BeautifulSoup(html, "html.parser")

for link in bsObject.find_all('img'):
  print(link.text.strip(), link.get('src'))

for link in bsObject.find_all('a'):
  print(link.text.strip(),link.get('img-alt'), link.get('article-title'),link.get('article-content'), link.get('article-region-name'),link.get('article-price'))
# Out:
#  https://www.facebook.com/tr?id=992961397411651&ev=PageView&noscript=1
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/logo-basic-24b18257ac4ef693c02233bf21e9cb7ecbf43ebd8d5b40c24d99e14094a44c81.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/search-icon-7008edd4f9aaa32188f55e65258f1c1905d7a9d1a3ca2a07ae809b5535380f14.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/apple-store-3a664174124650d63cae365bc55586fc5ff27b822b1b97788fc4af77d73d00c8.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/google-play-c9ad0fc573cd01e2b982df5de6709a3d8d7cec8d9b58a5c08db7da0b92a32a75.svg
#  https://dnvefa72aowie.cloudfront.net/origin/article/202108/F7905D288485B973B99862ABF7727F5FD45C859B9707A68337F98206FF5BF97B.jpg?q=82&s=300x300&t=crop
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/like-8111aa74d4b1045d7d5943a901896992574dd94c090cef92c26ae53e8da58260.svg
# ...

# %%
#노트북

html = urlopen("https://www.daangn.com/search/%EB%85%B8%ED%8A%B8%EB%B6%81")

bsObject = BeautifulSoup(html, "html.parser")

for link in bsObject.find_all('img'):
  print(link.text.strip(), link.get('src'))

for link in bsObject.find_all('a'):
  print(link.text.strip(),link.get('img-alt'), link.get('article-title'),link.get('article-content'), link.get('article-region-name'),link.get('article-price'))
# Out:
#  https://www.facebook.com/tr?id=992961397411651&ev=PageView&noscript=1
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/logo-basic-24b18257ac4ef693c02233bf21e9cb7ecbf43ebd8d5b40c24d99e14094a44c81.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/search-icon-7008edd4f9aaa32188f55e65258f1c1905d7a9d1a3ca2a07ae809b5535380f14.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/apple-store-3a664174124650d63cae365bc55586fc5ff27b822b1b97788fc4af77d73d00c8.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/google-play-c9ad0fc573cd01e2b982df5de6709a3d8d7cec8d9b58a5c08db7da0b92a32a75.svg
#  https://dnvefa72aowie.cloudfront.net/origin/article/202108/76D75CB52EB51F8694DC8EAD8A7DEDFDF10B8881DCF8270E20A26D4E12CF794A.jpg?q=82&s=300x300&t=crop
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/like-8111aa74d4b1045d7d5943a901896992574dd94c090cef92c26ae53e8da58260.svg
# ...

# %%
#아이패드

html = urlopen("https://www.daangn.com/search/%EC%95%84%EC%9D%B4%ED%8C%A8%EB%93%9C")

bsObject = BeautifulSoup(html, "html.parser")

for link in bsObject.find_all('img'):
  print(link.text.strip(), link.get('src'))

for link in bsObject.find_all('a'):
  print(link.text.strip(),link.get('img-alt'), link.get('article-title'),link.get('article-content'), link.get('article-region-name'),link.get('article-price'))
# Out:
#  https://www.facebook.com/tr?id=992961397411651&ev=PageView&noscript=1
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/logo-basic-24b18257ac4ef693c02233bf21e9cb7ecbf43ebd8d5b40c24d99e14094a44c81.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/search-icon-7008edd4f9aaa32188f55e65258f1c1905d7a9d1a3ca2a07ae809b5535380f14.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/apple-store-3a664174124650d63cae365bc55586fc5ff27b822b1b97788fc4af77d73d00c8.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/google-play-c9ad0fc573cd01e2b982df5de6709a3d8d7cec8d9b58a5c08db7da0b92a32a75.svg
#  https://dnvefa72aowie.cloudfront.net/origin/article/202108/E75B0E1680FBD7D2E041477A51D0CFD93C2ACD125F0F320612203191DE02E1B3.jpg?q=82&s=300x300&t=crop
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/like-8111aa74d4b1045d7d5943a901896992574dd94c090cef92c26ae53e8da58260.svg
# ...

# %%
#아이폰

html = urlopen("https://www.daangn.com/search/%EC%95%84%EC%9D%B4%ED%8F%B0")

bsObject = BeautifulSoup(html, "html.parser")

for link in bsObject.find_all('img'):
  print(link.text.strip(), link.get('src'))

for link in bsObject.find_all('a'):
  print(link.text.strip(),link.get('img-alt'), link.get('article-title'),link.get('article-content'), link.get('article-region-name'),link.get('article-price'))
# Out:
#  https://www.facebook.com/tr?id=992961397411651&ev=PageView&noscript=1
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/logo-basic-24b18257ac4ef693c02233bf21e9cb7ecbf43ebd8d5b40c24d99e14094a44c81.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/search-icon-7008edd4f9aaa32188f55e65258f1c1905d7a9d1a3ca2a07ae809b5535380f14.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/apple-store-3a664174124650d63cae365bc55586fc5ff27b822b1b97788fc4af77d73d00c8.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/google-play-c9ad0fc573cd01e2b982df5de6709a3d8d7cec8d9b58a5c08db7da0b92a32a75.svg
#  https://dnvefa72aowie.cloudfront.net/origin/article/202108/10FCC264E3B4B6BF036E97679B37BCAC80BDF51275114F838CDFE3F6039D941B.jpg?q=82&s=300x300&t=crop
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/like-8111aa74d4b1045d7d5943a901896992574dd94c090cef92c26ae53e8da58260.svg
# ...

# %%
#강남 명품가방

html = urlopen("https://www.daangn.com/search/%EA%B0%95%EB%82%A8%20%EB%AA%85%ED%92%88%EA%B0%80%EB%B0%A9")

bsObject = BeautifulSoup(html, "html.parser")

for link in bsObject.find_all('img'):
  print(link.text.strip(), link.get('src'))

for link in bsObject.find_all('a'):
  print(link.text.strip(),link.get('img-alt'), link.get('article-title'),link.get('article-content'), link.get('article-region-name'),link.get('article-price'))
# Out:
#  https://www.facebook.com/tr?id=992961397411651&ev=PageView&noscript=1
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/logo-basic-24b18257ac4ef693c02233bf21e9cb7ecbf43ebd8d5b40c24d99e14094a44c81.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/search-icon-7008edd4f9aaa32188f55e65258f1c1905d7a9d1a3ca2a07ae809b5535380f14.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/apple-store-3a664174124650d63cae365bc55586fc5ff27b822b1b97788fc4af77d73d00c8.svg
#  https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/google-play-c9ad0fc573cd01e2b982df5de6709a3d8d7cec8d9b58a5c08db7da0b92a32a75.svg
#  https://dnvefa72aowie.cloudfront.net/origin/article/202108/1d0fc3bc81f882ca4b24ffeed925980071005abc4a9d48dabc02f8d76d16a9b8.webp?q=82&s=300x300&t=crop
#  https://dnvefa72aowie.cloudfront.net/origin/article/202107/FCAEDEAA311168B361B7C44D617797C339DB0B7F000586B1CD662F088B226813.jpg?q=82&s=300x300&t=crop
# ...
